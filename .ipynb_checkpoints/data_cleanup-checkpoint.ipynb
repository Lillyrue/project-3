# %% [markdown]
# ### Project 3: Jobs and Salaries in Data Science
# ### About Dataset
#
# **work_year**: The year in which the data was recorded. This field indicates the temporal context of the data, important for understanding salary trends over time.
#
# **job_title**: The specific title of the job role, like 'Data Scientist', 'Data Engineer', or 'Data Analyst'. This column is crucial for understanding the salary distribution across various specialized roles within the data field.
#
# **job_category**: A classification of the job role into broader categories for easier analysis. This might include areas like 'Data Analysis', 'Machine Learning', 'Data Engineering', etc.
#
# **salary_currency**: The currency in which the salary is paid, such as USD, EUR, etc. This is important for currency conversion and understanding the actual value of the salary in a global context.
#
# **salary**: The annual gross salary of the role in the local currency. This raw salary figure is key for direct regional salary comparisons.
#
# **salary_in_usd**: The annual gross salary converted to United States Dollars (USD). This uniform currency conversion aids in global salary comparisons and analyses.
#
# **employee_residence**: The country of residence of the employee. This data point can be used to explore geographical salary differences and cost-of-living variations.
#
# **experience_level**: Classifies the professional experience level of the employee. Common categories might include 'Entry-level', 'Mid-level', 'Senior', and 'Executive', providing insight into how experience influences salary in data-related roles.
#
# **employment_type**: Specifies the type of employment, such as 'Full-time', 'Part-time', 'Contract', etc. This helps in analyzing how different employment arrangements affect salary structures.
#
# **work_setting**: The work setting or environment, like 'Remote', 'In-person', or 'Hybrid'. This column reflects the impact of work settings on salary levels in the data industry.
#
# **company_location**: The country where the company is located. It helps in analyzing how the location of the company affects salary structures.
#
# **company_size**: The size of the employer company, often categorized into small (S), medium (M), and large (L) sizes. This allows for analysis of how company size influences salary.
#
# Source: https://www.kaggle.com/datasets/hummaamqaasim/jobs-in-data

# %% [markdown]
# ### Import Libraries and Load Data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file into a Pandas DataFrame
data = pd.read_csv("Resources\jobs_in_data.csv")

# %%
# Take a look at data
data.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %% [markdown]
# ### Data Cleanup

# %%
# Check data size and type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# **Discussion:** As expected columns **work_year, salary** and **salary_in_usd** are type Int and the rest 9 columns are Strings.

# %%
# Check for null values per columm
data.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Check for N/A values per columm
data.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# **Discussion:** Data is clean because every cell has a value.

# %%
# Get summary statictics
data.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %% [markdown]
# **Discussion:** **work_year** column shows that the data collected is from 2020 to 2023 with most of the data being from 2023
# based on25% and 75% percentile. **salary** column statistics are not very useful because the values are in local currencies
# and should be converted to the same currency before comparison. **salary_in_usd** column statistics look as expected with
# most of the salaries between $105k and 186k.

# %%
# Create salary_in_usd box plot to check for outliers 
sns.boxplot(x=data['salary_in_usd'], palette = "Set1")
plt.show()

# %%
# Let's explore outliers
# Sort data
data_sorted = data.sort_values(by=['salary_in_usd'], ascending=False)
# Explore ourtlier with high salary
data_sorted.head(20)
# Out:
#       work_year                           job_title  \
# 9157       2020                  Research Scientist
# 7683       2022                        Data Analyst
# 5702       2023                  Analytics Engineer
# 9348       2021  Applied Machine Learning Scientist
# 9287       2021            Principal Data Scientist
# 9351       2020                      Data Scientist
# 9103       2022                 Data Analytics Lead
# 1696       2023                  Research Scientist
# 4938       2023       Analytics Engineering Manager
# 4267       2023           Machine Learning Engineer
# 1906       2023                   Research Engineer
# 1862       2023                       Data Engineer
# 6976       2023                        Data Analyst
# 2492       2023        Data Infrastructure Engineer
# 1912       2023                       Data Engineer
# 2710       2023                         ML Engineer
# 4100       2023                         ML Engineer
# ...

# %%
# Explore ourtlier with low salary
data_sorted.tail(20)
# Out:
#       work_year                          job_title               job_category  \
# 4622       2023                       AI Scientist    Machine Learning and AI
# 4743       2023                  Applied Scientist  Data Science and Research
# 9095       2020               Product Data Analyst              Data Analysis
# 9303       2021                      Data Engineer           Data Engineering
# 6857       2023                     Data Scientist  Data Science and Research
# 1468       2023                     Data Scientist  Data Science and Research
# 8577       2021  Computer Vision Software Engineer    Machine Learning and AI
# 9327       2021           Computer Vision Engineer    Machine Learning and AI
# 4194       2023                         BI Analyst       BI and Visualization
# 6856       2023                       Data Analyst              Data Analysis
# 1945       2023                      Data Engineer           Data Engineering
# ...

# %% [markdown]
# **Outliers:** The outiers with high salary are assosiated with executive, senior and R&D positions. The outiers with low salary are assosiated with part-time or low cost GEOs jobs. Our team did't notice any data anomalies associate with outliers at both ends, so we will keep them all in the dataset for now.

# %% [markdown]
# **Duplicates:** No need to check for duplicates because there is no unique column or ID column.

# %% [markdown]
# **Discussion about the data cleanup:** jobs_in_data.csv data is clean because every cell has a value with correct data type per each column. Aslo there is not any duplicates or outliers. Further data exploration is needed to properly select a data set for data analysis.

# %% [markdown]
# ### Data Exploration and Preparation

# %%
# Create new df to select data for further analysis and data visualization
data_for_analysis = data.copy()
data_for_analysis.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
# Creat job cateory summary
job_category_freq = data['job_category'].value_counts()
job_category_freq
# Out:
# job_category
# Data Science and Research         3014
# Data Engineering                  2260
# Data Analysis                     1457
# Machine Learning and AI           1428
# Leadership and Management          503
# BI and Visualization               313
# Data Architecture and Modeling     259
# Data Management and Strategy        61
# Data Quality and Operations         55
# Cloud and Database                   5
# Name: count, dtype: int64

# %%
# Plot the number of rows per job_category
sns.countplot(data=data, x='job_category',  order=data['job_category'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %%
# Check job_title clm for the sevral defernt job titles that mean the same thing or 
# have some errors 
job_title_freq = data['job_title'].value_counts()
print(f"Total number of unique job tites is {job_title_freq.size}")
job_title_freq.head(50)
# Out:
# Total number of unique job tites is 125
# job_title
# Data Engineer                               2195
# Data Scientist                              1989
# Data Analyst                                1388
# Machine Learning Engineer                    991
# Applied Scientist                            272
# Research Scientist                           269
# Analytics Engineer                           256
# Data Architect                               213
# Business Intelligence Engineer               144
# Research Engineer                            144
# Data Manager                                 132
# ML Engineer                                  106
# Data Science Manager                          88
# Machine Learning Scientist                    76
# Business Intelligence Analyst                 54
# BI Developer                                  52
# Data Science Consultant                       44
# Data Specialist                               40
# ...

# %%
# Coumt the number of job titles per job category
data.groupby(['job_category'])['job_title'].nunique()
# Out:
# job_category
# BI and Visualization              11
# Cloud and Database                 1
# Data Analysis                     14
# Data Architecture and Modeling     7
# Data Engineering                  15
# Data Management and Strategy       5
# Data Quality and Operations        6
# Data Science and Research         23
# Leadership and Management         14
# Machine Learning and AI           29
# Name: job_title, dtype: int64

# %%
# Count the total number of unique job tittles per job category
data.groupby(['job_category'])['job_title'].nunique().sum()
# Out:
# 125

# %% [markdown]
# **Discussion:** Each job title appears just once per job category.<br>
# **Keep:** both **job_category** and **job_title** columns.

# %%
# Count the number of rows per year
data_for_analysis['work_year'].value_counts()
# Out:
# work_year
# 2023    7453
# 2022    1634
# 2021     197
# 2020      71
# Name: count, dtype: int64

# %%
# % data for 2023
(1-(9355-7453)/9355)*100
# Out:
# 79.66862640299304

# %%
# Plot the number of rows per year
sns.countplot(x = data_for_analysis['work_year'], order=data_for_analysis['work_year'].value_counts().index, palette = "Set1")
plt.show()

# %% [markdown]
# **Discussion:** About 80% of the data are for 2023. Team agreed to keep only
#     2023 data for further analytics. <br>
# **Drop: work_year** rows not equal to 2023.
# **Drop: work_year** column due to redundunt information.

# %%
# Update data preparation df
data_for_analysis = data_for_analysis.loc[data_for_analysis['work_year'] == 2023]
data_for_analysis = data_for_analysis.drop(columns = ['work_year'])
data_for_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7453 entries, 0 to 7496
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           7453 non-null   object
#  1   job_category        7453 non-null   object
#  2   salary_currency     7453 non-null   object
#  3   salary              7453 non-null   int64
#  4   salary_in_usd       7453 non-null   int64
#  5   employee_residence  7453 non-null   object
#  6   experience_level    7453 non-null   object
#  7   employment_type     7453 non-null   object
#  8   work_setting        7453 non-null   object
#  9   company_location    7453 non-null   object
#  10  company_size        7453 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 698.7+ KB

# %%
# Count the number of rows per currency
data_for_analysis['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    7022
# GBP     246
# EUR     156
# CAD      15
# AUD       3
# PLN       3
# BRL       3
# CHF       2
# SGD       2
# TRY       1
# Name: count, dtype: int64

# %%
# % data for salary currency in USD
(1-(7453-7022)/7453)*100
# Out:
# 94.21709378773649

# %%
# Plot the number of rows per currency
sns.countplot(x = data_for_analysis['salary_currency'], order=data_for_analysis['salary_currency'].value_counts().index, palette = "Set1")
plt.show()

# %% [markdown]
# **Discussion:**  About 94% of the data are for salary currency in USD. Team agreed to keep only data in USD for further analytics.
# **Drop: salary_currency** rows not equal to USD
# **Drop: salary_currency** and **salary_in_usd** columns due to reduncy and
# **Keep: salary** column with salary values in USD

# %%
# Update data preparation df
data_for_analysis = data_for_analysis.loc[data_for_analysis['salary_currency'] == 'USD']
data_for_analysis = data_for_analysis.drop(columns = ['salary_currency', 'salary_in_usd'])
data_for_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7022 entries, 1 to 7496
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           7022 non-null   object
#  1   job_category        7022 non-null   object
#  2   salary              7022 non-null   int64
#  3   employee_residence  7022 non-null   object
#  4   experience_level    7022 non-null   object
#  5   employment_type     7022 non-null   object
#  6   work_setting        7022 non-null   object
#  7   company_location    7022 non-null   object
#  8   company_size        7022 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 548.6+ KB

# %%
# Count the number of rows per employee_residence
data_for_analysis['employee_residence'].value_counts()
# Out:
# employee_residence
# United States             6644
# Canada                     156
# United Kingdom             100
# Colombia                    14
# France                       9
# Germany                      8
# Australia                    8
# India                        7
# Ukraine                      7
# Mexico                       6
# Argentina                    6
# Nigeria                      6
# Spain                        6
# Brazil                       4
# Portugal                     3
# Kenya                        2
# Turkey                       2
# South Africa                 2
# Poland                       2
# Sweden                       2
# Armenia                      2
# Uzbekistan                   2
# Saudi Arabia                 2
# Ireland                      2
# South Korea                  2
# Egypt                        1
# Georgia                      1
# Netherlands                  1
# Kuwait                       1
# ...

# %%
# Plot the number of rows employee_residence
sns.countplot(x = data_for_analysis['employee_residence'], order=data_for_analysis['employee_residence'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %%
# Count the number of rows per company_location
data_for_analysis['company_location'].value_counts()
# Out:
# company_location
# United States             6659
# Canada                     156
# United Kingdom             100
# Colombia                    14
# France                      10
# Australia                   10
# Germany                      8
# Spain                        6
# Mexico                       6
# Ukraine                      6
# India                        4
# Argentina                    4
# Nigeria                      4
# Brazil                       4
# Portugal                     3
# Russia                       3
# Sweden                       2
# Ireland                      2
# Saudi Arabia                 2
# South Korea                  2
# Kenya                        2
# Netherlands                  2
# Poland                       2
# South Africa                 2
# Armenia                      1
# Japan                        1
# Qatar                        1
# Ghana                        1
# Turkey                       1
# ...

# %%
# Plot the number of rows company_location
sns.countplot(x = data_for_analysis['company_location'],order=data_for_analysis['company_location'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Discussion:** Over 95% of employees and companies are located in US. Team agreed to keep only US data for further analytics. <br>
# **Drop: employee_residence** and **company_location** rows not equal to United States <br>
# **Drop: employee_residence** and **company_location** columns due to the lack of information <br>

# %%
# Update data preparation df
data_for_analysis = data_for_analysis.loc[data_for_analysis['employee_residence'] == 'United States']
data_for_analysis = data_for_analysis.loc[data_for_analysis['company_location'] == 'United States']
data_for_analysis = data_for_analysis.drop(columns = ['employee_residence', 'company_location'])
data_for_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6642 entries, 1 to 7496
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         6642 non-null   object
#  1   job_category      6642 non-null   object
#  2   salary            6642 non-null   int64
#  3   experience_level  6642 non-null   object
#  4   employment_type   6642 non-null   object
#  5   work_setting      6642 non-null   object
#  6   company_size      6642 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 415.1+ KB

# %%
# Count the number of rows per employment_type
data_for_analysis['employment_type'].value_counts()
# Out:
# employment_type
# Full-time    6635
# Contract        5
# Part-time       2
# Name: count, dtype: int64

# %%
# Plot the number of rows per employment_type
sns.countplot(x = data_for_analysis['employment_type'], order=data_for_analysis['employment_type'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Discussion:** Over 99% data are for full-time employees. Team agreed to keep only Full_time data for further analytics. <br>
# **Drop: employment_type** rows not equal to Full-time <br>
# **Drop: employment_type** column due to redundant information

# %%
# Update data preparation df
data_for_analysis = data_for_analysis.loc[data_for_analysis['employment_type'] == 'Full-time']
data_for_analysis = data_for_analysis.drop(columns = ['employment_type'])
data_for_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6635 entries, 1 to 7496
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         6635 non-null   object
#  1   job_category      6635 non-null   object
#  2   salary            6635 non-null   int64
#  3   experience_level  6635 non-null   object
#  4   work_setting      6635 non-null   object
#  5   company_size      6635 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 362.9+ KB

# %%
# Plot the number of rows per experience_level
sns.countplot(x = data_for_analysis['experience_level'], order=data_for_analysis['experience_level'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %%
# Plot the number of rows per work_setting
sns.countplot(x = data_for_analysis['work_setting'], order=data_for_analysis['work_setting'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %%
# Plot the number of rows per company_size
sns.countplot(x = data_for_analysis['company_size'], order=data_for_analysis['company_size'].value_counts().index, palette = "Set1")
plt.show()

# %% [markdown]
# **Discussion:** experience_level, work_setting and company_size colums have data unevenly distributed between column parameters. However, the team decided to keep all the data for this colums for further analytics. <br>
# **Keep: experience_level, work_setting and company_size** rows with all the data <br>

# %% [markdown]
# ### Final df Exploration

# %%
# Count the number of rows per job_category
data_for_analysis['job_category'].value_counts()
# Out:
# job_category
# Data Science and Research         2177
# Data Engineering                  1526
# Machine Learning and AI           1031
# Data Analysis                      974
# Leadership and Management          369
# BI and Visualization               284
# Data Architecture and Modeling     189
# Data Management and Strategy        44
# Data Quality and Operations         38
# Cloud and Database                   3
# Name: count, dtype: int64

# %%
# Plot the number of rows per job_category
sns.countplot(x=data_for_analysis['job_category'], order=data_for_analysis['job_category'].value_counts().index, palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %%
# Check job_title clm for the sevral defernt job titles that mean the same thing or 
# have some errors 
job_title_freq = data_for_analysis['job_title'].value_counts()
print(f"Total number of unique job tites is {job_title_freq.size}")
job_title_freq.head(50)
# Out:
# Total number of unique job tites is 78
# job_title
# Data Engineer                               1502
# Data Scientist                              1360
# Data Analyst                                 966
# Machine Learning Engineer                    779
# Applied Scientist                            252
# Research Scientist                           233
# Analytics Engineer                           176
# Data Architect                               152
# Business Intelligence Engineer               140
# Research Engineer                            126
# Data Manager                                 116
# ML Engineer                                   81
# Data Science Manager                          50
# Business Intelligence Analyst                 48
# Machine Learning Scientist                    48
# BI Developer                                  44
# Decision Scientist                            36
# Research Analyst                              33
# ...

# %%
# Create salary_in_usd box plot to check for outliers 
sns.boxplot(x=data_for_analysis['salary'], palette = "Set1")
plt.show()

# %%
# Let's explore outliers
# Sort data
data_for_analysis_sorted = data_for_analysis.sort_values(by=['salary'], ascending=False)
# Explore ourtlier with high salary
data_for_analysis_sorted.head(20)
# Out:
#                          job_title                    job_category  salary  \
# 1696            Research Scientist       Data Science and Research  405000
# 4267     Machine Learning Engineer         Machine Learning and AI  392000
# 6976                  Data Analyst                   Data Analysis  385000
# 2710                   ML Engineer         Machine Learning and AI  385000
# 1912                 Data Engineer                Data Engineering  385000
# 1906             Research Engineer       Data Science and Research  385000
# 2492  Data Infrastructure Engineer                Data Engineering  385000
# 1862                 Data Engineer                Data Engineering  385000
# 4100                   ML Engineer         Machine Learning and AI  383910
# 6345                Data Architect  Data Architecture and Modeling  376080
# 2622      Director of Data Science       Data Science and Research  375500
# ...

# %%
# Explore ourtlier with low salary
data_for_analysis_sorted.tail(20)
# Out:
#                           job_title                  job_category  salary  \
# 1526                  Data Engineer              Data Engineering   50000
# 1136                   Data Analyst                 Data Analysis   49000
# 1800                   Data Analyst                 Data Analysis   49000
# 3198                 Data Scientist     Data Science and Research   48915
# 1502                   Data Analyst                 Data Analysis   48000
# 6802                   Data Analyst                 Data Analysis   48000
# 6968                   Data Analyst                 Data Analysis   48000
# 2203                   Data Analyst                 Data Analysis   46500
# 2825                   Data Analyst                 Data Analysis   46500
# 1631    Data Integration Specialist  Data Management and Strategy   46400
# 5392    Data Integration Specialist  Data Management and Strategy   46400
# 3570               Research Analyst     Data Science and Research   45000
# ...

# %% [markdown]
# **Outliers:** The outiers with high salary are assosiated with executive, senior and R&D positions. The outiers with low salary are assosiated with entery and mid-level jobs. Our team did't notice any data anomalies associate with outliers at both ends, so we will keep them all in the dataset.

# %%
# Rename salary column to better discribe the data
data_for_analysis.rename(columns = {'salary':'US_salary_2023'}, inplace = True)
# Final data_for_analysis df summary
data_for_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6635 entries, 1 to 7496
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         6635 non-null   object
#  1   job_category      6635 non-null   object
#  2   US_salary_2023    6635 non-null   int64
#  3   experience_level  6635 non-null   object
#  4   work_setting      6635 non-null   object
#  5   company_size      6635 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 362.9+ KB

# %% [markdown]
# **Conclusion:** During data exploration and preparation step the number of colums was reduced from 12 to 6 due to redundant information and the number of rows was reduced from 9355 to 6635 due to insufficient amount of data per category. Further data analysis of salaries in data will be focussed on companies and full-time employees located in US for year 2023. Final df has the same 10 job categories as an original df; however, unique job_title reduced from 125 to 78 as expected during row reduction per job location, currency and job type. There is not any outliers associate with data anomalies. Final df analysis will be presended in Data Visualization Section of the report.

# %%
# Save data prepared for analysis to csv
data_for_analysis.to_csv('output_data\jobs_in_data_ready_for_analysis.csv', index = False)
