# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd #import pandas

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo['jobs_in_data']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['jobs']

# %%
datascijobs = db['jobs']

# %%
query = {'work_year' : 2023}

# Use count_documents to display the number of documents in the result
result = datascijobs.count_documents(query)
# Display the first document in the results using pprint
pprint(result)
# Out:
# 6635

# %%
cleaned_df = pd.DataFrame(datascijobs.find(query))
cleaned_df.head(15)
# Out:
#                          _id  work_year                    job_title  \
# 0   65a2ea278609c11c210752cb       2023               Data Architect
# 1   65a2ea278609c11c210752cc       2023               Data Architect
# 2   65a2ea278609c11c210752cd       2023               Data Scientist
# 3   65a2ea278609c11c210752ce       2023               Data Scientist
# 4   65a2ea278609c11c210752cf       2023               Data Scientist
# 5   65a2ea278609c11c210752d0       2023               Data Scientist
# 6   65a2ea278609c11c210752d1       2023  Machine Learning Researcher
# 7   65a2ea278609c11c210752d2       2023  Machine Learning Researcher
# 8   65a2ea278609c11c210752d3       2023                Data Engineer
# 9   65a2ea278609c11c210752d4       2023                Data Engineer
# 10  65a2ea278609c11c210752d5       2023    Machine Learning Engineer
# 11  65a2ea278609c11c210752d6       2023    Machine Learning Engineer
# 12  65a2ea278609c11c210752d7       2023                 Data Analyst
# ...

# %%
job_title = 'Data Analyst'
work_experience = 3

employees = session.query(Employee).filter_by(job_title=job_title, work_experience=work_experience).all()

total_salary = 0
for employee in employees:
    total_salary += employee.salary

average_salary = total_salary / len(employees)

print(f"The average salary for {job_title}s with {work_experience} years of experience is ${average_salary}.")
